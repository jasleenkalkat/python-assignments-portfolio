# %%
def gradient_descent(x0, y0, f, grad_f, alpha, num_iterations):
    """
    Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0  # Initialize x and y with the initial point
    
    for i in range(num_iterations):
        # Obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f(x, y)
        
        # Update x and y using the gradient descent formula
        x -= alpha * grad_x
        y -= alpha * grad_y
        
        # Optional: Print progress for debugging
        print(f"Iteration {i+1}: x = {x}, y = {y}, f(x, y) = {f(x, y)}")
    
    return x, y

# %%
# Define the function
def fun_1(x, y):
    return x**2 + y**2

# Define gradient
def grad_f_1(x, y):
    grad_x = 2 * x
    grad_y = 2 * y
    return grad_x, grad_y

# Gradient descent function
def gradient_descent(x0, y0, f, grad_f, alpha, num_iterations):
    """
    Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0  
    
    for i in range(num_iterations):
       
        grad_x, grad_y = grad_f(x, y)
        
       
        x -= alpha * grad_x
        y -= alpha * grad_y
        
    
    return x, y

# Test Case 1: (x0, y0) = (0.1, 0.1), α = 0.1, iterations = 10
x_final, y_final = gradient_descent(0.1, 0.1, fun_1, grad_f_1, 0.1, 10)
print(f"Final Point (Test Case 1): ({x_final}, {y_final})")

# Test Case 2: (x0, y0) = (-1, 1), α = 0.01, iterations = 100
x_final, y_final = gradient_descent(-1, 1, fun_1, grad_f_1, 0.01, 100)
print(f"Final Point (Test Case 2): ({x_final}, {y_final})")
# Out:
# Final Point (Test Case 1): (0.010737418240000003, 0.010737418240000003)
# Final Point (Test Case 2): (-0.13261955589475316, 0.13261955589475316)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function f2(x, y)
def fun_2(x, y):
    return 1 - np.exp(-x**2 - (y - 2)**2) - 2 * np.exp(-x**2 - (y + 2)**2)

# Define its gradient
def grad_f_2(x, y):
    grad_x = 2 * x * np.exp(-x**2 - (y - 2)**2) + 4 * x * np.exp(-x**2 - (y + 2)**2)
    grad_y = 2 * (y - 2) * np.exp(-x**2 - (y - 2)**2) + 4 * (y + 2) * np.exp(-x**2 - (y + 2)**2)
    return grad_x, grad_y

def gradient_descent(x0, y0, f, grad_f, alpha, num_iterations):
    x, y = x0, y0
    
    for i in range(num_iterations):
        grad_x, grad_y = grad_f(x, y)
        x -= alpha * grad_x
        y -= alpha * grad_y
        
        if i % 1000 == 0:
            print(f"Iteration {i}: x = {x}, y = {y}, f(x, y) = {f(x, y)}")
    
    return x, y

print("Running Test Case 1...")
x_final, y_final = gradient_descent(0, 1, fun_2, grad_f_2, 0.01, 10000)
print(f"Final Point (Test Case 1): ({x_final}, {y_final})")

print("Running Test Case 2...")
x_final, y_final = gradient_descent(0, -1, fun_2, grad_f_2, 0.01, 10000)
print(f"Final Point (Test Case 2): ({x_final}, {y_final})")

X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun_2(x, y)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f2(x, y)')
plt.title('3D Plot of f2(x, y)')
plt.show()
# Out:
# Running Test Case 1...
# Iteration 0: x = 0.0, y = 1.0073427796469385, f(x, y) = 0.626462137848364
# Iteration 1000: x = 0.0, y = 1.9999990964673227, f(x, y) = -2.2507115996454697e-07
# Iteration 2000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 3000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 4000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 5000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 6000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 7000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 8000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Iteration 9000: x = 0.0, y = 1.9999990997123154, f(x, y) = -2.250711600058753e-07
# Final Point (Test Case 1): (0.0, 1.9999990997123154)
# Running Test Case 2...
# ...
